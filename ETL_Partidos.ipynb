# %% [markdown]
# # ETL Partidos Atletico de Madrid

# %% [markdown]
# ### Extraccion de los datos

# %%
# Importamos las librerias necesarias
from bs4 import BeautifulSoup as bs4
import requests
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
# Creamos la url
temporada="2023-2024"
url=f"https://fbref.com/en/squads/db3b9613/{temporada}/Atletico-Madrid-Stats"

# %%
# Realizamos la peticion
peticion=requests.get(url)

# %%
# Comprobamos que el servidor esta OK
if peticion.status_code!=200:
    
    raise Exception("La pagina no esta accesible")

# %%
# Obtenemos el html
soup=bs4(peticion.text,"html.parser")

# %%
# Obtenemos la etiqueta de la tabla
tabla=soup.find(id="matchlogs_for")

# %%
# Obtenemos los nombres de las columnas
try:
    
    cabecera=tabla.find("thead").find("tr")

except AttributeError as e:
    
    raise Exception(f"No hay partidos de la temporada {temporada}")
    
columnas=[columna.text for columna in cabecera.find_all("th")]

# %%
# Obtenemos las filas de la tabla
body=tabla.find("tbody")
filas=body.find_all("tr")

# %%
# Funcion para extraer el contenido de las filas de la tabla
def extraerData(fila:str)->list[str]:
    
    fecha=fila.find("th").text
    
    return [fecha]+[columna.text for columna in fila.find_all("td")]

registros=list(map(extraerData, filas))

# %%
# Creamos un dataframe a partir de los registros
df=pd.DataFrame(registros, columns=columnas)

# %%
df
# Out:
#           Date    Time          Comp         Round  Day Venue Result GF GA  \
# 0   2023-08-14  21:30        La Liga   Matchweek 1  Mon  Home      W  3  1
# 1   2023-08-20  21:30        La Liga   Matchweek 2  Sun  Away      D  0  0
# 2   2023-08-28  21:30        La Liga   Matchweek 3  Mon  Away      W  7  0
# 3   2023-09-16  16:15        La Liga   Matchweek 5  Sat  Away      L  0  3
# 4   2023-09-19  21:00   Champions Lg   Group stage  Tue  Away      D  1  1
# 5   2023-09-24  21:00        La Liga   Matchweek 6  Sun  Home      W  3  1
# 6   2023-09-28  21:30        La Liga   Matchweek 7  Thu  Away      W  2  0
# 7   2023-10-01  21:00        La Liga   Matchweek 8  Sun  Home      W  3  2
# 8   2023-10-04  18:45   Champions Lg   Group stage  Wed  Home      W  3  2
# 9   2023-10-08  16:15        La Liga   Matchweek 9  Sun  Home      W  2  1
# 10  2023-10-21  21:00        La Liga  Matchweek 10  Sat  Away
# 11  2023-10-25  20:00   Champions Lg   Group stage  Wed  Away
# 12  2023-10-29  21:00        La Liga  Matchweek 11  Sun  Home
# 13  2023-11-03  20:00        La Liga  Matchweek 12  Fri  Away
# 14  2023-11-07  21:00   Champions Lg   Group stage  Tue  Home
# 15  2023-11-12               La Liga  Matchweek 13  Sun  Home
# 16  2023-11-26               La Liga  Matchweek 14  Sun  Home
# 17  2023-11-28  21:00   Champions Lg   Group stage  Tue  Away
# 18  2023-12-03               La Liga  Matchweek 15  Sun  Away
# 19  2023-12-10               La Liga  Matchweek 16  Sun  Home
# 20  2023-12-13  21:00   Champions Lg   Group stage  Wed  Home
# 21  2023-12-17               La Liga  Matchweek 17  Sun  Away
# 22  2023-12-20               La Liga  Matchweek 18  Wed  Home
# 23  2023-12-23  16:15        La Liga   Matchweek 4  Sat  Home
# 24  2024-01-03               La Liga  Matchweek 19  Wed  Away
# 25  2024-01-14               La Liga  Matchweek 20  Sun  Home
# 26  2024-01-21               La Liga  Matchweek 21  Sun  Away
# 27  2024-01-28               La Liga  Matchweek 22  Sun  Home
# 28  2024-02-04               La Liga  Matchweek 23  Sun  Away
# 29  2024-02-11               La Liga  Matchweek 24  Sun  Away
# 30  2024-02-18               La Liga  Matchweek 25  Sun  Home
# 31  2024-02-25               La Liga  Matchweek 26  Sun  Away
# 32  2024-03-03               La Liga  Matchweek 27  Sun  Home
# 33  2024-03-10               La Liga  Matchweek 28  Sun  Away
# 34  2024-03-17               La Liga  Matchweek 29  Sun  Home
# 35  2024-03-31               La Liga  Matchweek 30  Sun  Away
# 36  2024-04-14               La Liga  Matchweek 31  Sun  Home
# 37  2024-04-21               La Liga  Matchweek 32  Sun  Away
# 38  2024-04-28               La Liga  Matchweek 33  Sun  Home
# 39  2024-05-05               La Liga  Matchweek 34  Sun  Away
# 40  2024-05-12               La Liga  Matchweek 35  Sun  Home
# 41  2024-05-15               La Liga  Matchweek 36  Wed  Away
# 42  2024-05-19               La Liga  Matchweek 37  Sun  Home
# 43  2024-05-26               La Liga  Matchweek 38  Sun  Away
#
#           Opponent   xG  xGA Poss Attendance    Captain Formation  \
# 0          Granada  2.4  0.9   46     56,164       Koke     3-5-2
# 1            Betis  0.5  0.7   47     51,782  Jan Oblak     5-3-2
# 2   Rayo Vallecano  3.4  0.6   44     13,966  Jan Oblak     5-3-2
# 3         Valencia  0.6  1.3   63     45,363  Jan Oblak     5-3-2
# 4         it Lazio  0.9  1.2   51     46,168  Jan Oblak     5-3-2
# 5      Real Madrid  1.4  1.0   37     69,082       Koke     5-3-2
# 6          Osasuna  1.5  1.0   45     20,192       Koke     5-3-2
# 7            Cádiz  2.7  0.8   69     53,421       Koke     3-5-2
# 8     nl Feyenoord  0.8  2.4   48     61,742       Koke     3-5-2
# 9    Real Sociedad  2.2  1.2   38     65,607       Koke     3-5-2
# 10      Celta Vigo
# 11      sct Celtic
# 12          Alavés
# 13      Las Palmas
# 14      sct Celtic
# 15      Villarreal
# 16        Mallorca
# 17    nl Feyenoord
# 18       Barcelona
# 19         Almería
# 20        it Lazio
# 21   Athletic Club
# 22          Getafe
# 23         Sevilla
# 24          Girona
# 25  Rayo Vallecano
# 26         Granada
# 27        Valencia
# 28     Real Madrid
# 29         Sevilla
# 30      Las Palmas
# 31         Almería
# 32           Betis
# 33           Cádiz
# 34       Barcelona
# 35      Villarreal
# 36          Girona
# 37          Alavés
# 38   Athletic Club
# 39        Mallorca
# 40      Celta Vigo
# 41          Getafe
# 42         Osasuna
# 43   Real Sociedad
#
#               Referee  Match Report Notes
# 0         Juan Pulido  Match Report
# 1   Ricardo de Burgos  Match Report
# 2   José Luis Munuera  Match Report
# 3           Jesús Gil  Match Report
# 4       Slavko Vinčič  Match Report
# 5      Alberola Rojas  Match Report
# 6       Juan Martínez  Match Report
# 7   Javier Villanueva  Match Report
# 8   François Letexier  Match Report
# 9   José Luis Munuera  Match Report
# 10                     Head-to-Head
# 11                     Head-to-Head
# 12                     Head-to-Head
# 13                     Head-to-Head
# 14                     Head-to-Head
# 15                     Head-to-Head
# 16                     Head-to-Head
# 17                     Head-to-Head
# 18                     Head-to-Head
# 19                     Head-to-Head
# 20                     Head-to-Head
# 21                     Head-to-Head
# 22                     Head-to-Head
# 23                     Head-to-Head
# 24                     Head-to-Head
# 25                     Head-to-Head
# 26                     Head-to-Head
# 27                     Head-to-Head
# 28                     Head-to-Head
# 29                     Head-to-Head
# 30                     Head-to-Head
# 31                     Head-to-Head
# 32                     Head-to-Head
# 33                     Head-to-Head
# 34                     Head-to-Head
# 35                     Head-to-Head
# 36                     Head-to-Head
# 37                     Head-to-Head
# 38                     Head-to-Head
# 39                     Head-to-Head
# 40                     Head-to-Head
# 41                     Head-to-Head
# 42                     Head-to-Head
# 43                     Head-to-Head

# %% [markdown]
# ### Limpieza de los datos

# %%
# Seleccionamos las columnas que queremos
df=df[["Date","Time","Comp","Round","Venue","Result","GF","GA","Opponent","Poss","Attendance","Captain","Referee"]]

# %%
# Renombramos las columnas
df.rename({"Date":"Fecha", "Time":"Hora", "Comp":"Competicion","Round":"Ronda", "Venue":"Lugar", "Result":"Resultado",
           "GF":"Goles Marcados", "GA":"Goles Recibidos", "Opponent":"Rival", "Poss":"Posesion",
          "Attendance":"Publico", "Captain":"Capitan", "Referee":"Arbitro"}, axis=1, inplace=True)
df.head()
# Out:
#         Fecha    Hora   Competicion        Ronda Lugar Resultado  \
# 0  2023-08-14  21:30        La Liga  Matchweek 1  Home         W
# 1  2023-08-20  21:30        La Liga  Matchweek 2  Away         D
# 2  2023-08-28  21:30        La Liga  Matchweek 3  Away         W
# 3  2023-09-16  16:15        La Liga  Matchweek 5  Away         L
# 4  2023-09-19  21:00   Champions Lg  Group stage  Away         D
#
#   Goles Marcados Goles Recibidos           Rival Posesion Publico    Capitan  \
# 0              3               1         Granada       46  56,164       Koke
# 1              0               0           Betis       47  51,782  Jan Oblak
# 2              7               0  Rayo Vallecano       44  13,966  Jan Oblak
# 3              0               3        Valencia       63  45,363  Jan Oblak
# 4              1               1        it Lazio       51  46,168  Jan Oblak
#
#              Arbitro
# 0        Juan Pulido
# 1  Ricardo de Burgos
# 2  José Luis Munuera
# 3          Jesús Gil
# 4      Slavko Vinčič

# %%
# Observamos si hay partidos sin jugar (no tiene resultado)
df[df["Resultado"]==""].head()
# Out:
#          Fecha    Hora   Competicion         Ronda Lugar Resultado  \
# 10  2023-10-21  21:00        La Liga  Matchweek 10  Away
# 11  2023-10-25  20:00   Champions Lg   Group stage  Away
# 12  2023-10-29  21:00        La Liga  Matchweek 11  Home
# 13  2023-11-03  20:00        La Liga  Matchweek 12  Away
# 14  2023-11-07  21:00   Champions Lg   Group stage  Home
#
#    Goles Marcados Goles Recibidos       Rival Posesion Publico Capitan Arbitro
# 10                                 Celta Vigo
# 11                                 sct Celtic
# 12                                     Alavés
# 13                                 Las Palmas
# 14                                 sct Celtic

# %%
# Obtenemos los partidos que se han jugado
df_jugados=df[df["Resultado"]!=""]
df_jugados.head()
# Out:
#         Fecha    Hora   Competicion        Ronda Lugar Resultado  \
# 0  2023-08-14  21:30        La Liga  Matchweek 1  Home         W
# 1  2023-08-20  21:30        La Liga  Matchweek 2  Away         D
# 2  2023-08-28  21:30        La Liga  Matchweek 3  Away         W
# 3  2023-09-16  16:15        La Liga  Matchweek 5  Away         L
# 4  2023-09-19  21:00   Champions Lg  Group stage  Away         D
#
#   Goles Marcados Goles Recibidos           Rival Posesion Publico    Capitan  \
# 0              3               1         Granada       46  56,164       Koke
# 1              0               0           Betis       47  51,782  Jan Oblak
# 2              7               0  Rayo Vallecano       44  13,966  Jan Oblak
# 3              0               3        Valencia       63  45,363  Jan Oblak
# 4              1               1        it Lazio       51  46,168  Jan Oblak
#
#              Arbitro
# 0        Juan Pulido
# 1  Ricardo de Burgos
# 2  José Luis Munuera
# 3          Jesús Gil
# 4      Slavko Vinčič

# %%
# Limpiamos la competicion
competicion={"Champions Lg":"Champions League", "UEFA Cup":"Europa League", "Europa Lg":"Europa League"}
df_jugados["Competicion"]=df_jugados["Competicion"].apply(lambda x: competicion[x] if x in competicion.keys() else x)

# %%
# Funcion para limpiar la ronda
def limpiarRonda(ronda:str)->str:
    
    rondas={"First round":"Primera Ronda", "Second round":"Segunda Ronda", "Third round":"Tercera Ronda",
            "Play-off round":"Ronda de playoff", "Group stage":"Fase de grupos", "Round of 32":"Dieciseisavos de final",
            "Round of 16":"Octavos de final", "Quarter-finals":"Cuartos de final", "Semi-finals":"Semifinales", "Final":"Final"}
    
    if "Matchweek" in ronda:
        
        numero=ronda.split(" ")[1]
        
        return f"Jornada {numero}"
    
    elif "qualifying" in ronda:
        
        return "Fase previa"
    
    elif ronda in rondas.keys():
        
        return rondas[ronda]
    
    else:
        
        print(ronda)
        
        return ronda
    
df_jugados["Ronda"]=df_jugados["Ronda"].apply(limpiarRonda)
df_jugados.head()
# Out:
#         Fecha    Hora       Competicion           Ronda Lugar Resultado  \
# 0  2023-08-14  21:30            La Liga       Jornada 1  Home         W
# 1  2023-08-20  21:30            La Liga       Jornada 2  Away         D
# 2  2023-08-28  21:30            La Liga       Jornada 3  Away         W
# 3  2023-09-16  16:15            La Liga       Jornada 5  Away         L
# 4  2023-09-19  21:00   Champions League  Fase de grupos  Away         D
#
#   Goles Marcados Goles Recibidos           Rival Posesion Publico    Capitan  \
# 0              3               1         Granada       46  56,164       Koke
# 1              0               0           Betis       47  51,782  Jan Oblak
# 2              7               0  Rayo Vallecano       44  13,966  Jan Oblak
# 3              0               3        Valencia       63  45,363  Jan Oblak
# 4              1               1        it Lazio       51  46,168  Jan Oblak
#
#              Arbitro
# 0        Juan Pulido
# 1  Ricardo de Burgos
# 2  José Luis Munuera
# 3          Jesús Gil
# 4      Slavko Vinčič

# %%
# Limpiamos el lugar
lugares={"Home":"Local", "Away":"Visitante"}
df_jugados["Lugar"]=df_jugados["Lugar"].apply(lambda x: lugares[x] if x in lugares.keys() else x)
df_jugados.head()
# Out:
#         Fecha    Hora       Competicion           Ronda      Lugar Resultado  \
# 0  2023-08-14  21:30            La Liga       Jornada 1      Local         W
# 1  2023-08-20  21:30            La Liga       Jornada 2  Visitante         D
# 2  2023-08-28  21:30            La Liga       Jornada 3  Visitante         W
# 3  2023-09-16  16:15            La Liga       Jornada 5  Visitante         L
# 4  2023-09-19  21:00   Champions League  Fase de grupos  Visitante         D
#
#   Goles Marcados Goles Recibidos           Rival Posesion Publico    Capitan  \
# 0              3               1         Granada       46  56,164       Koke
# 1              0               0           Betis       47  51,782  Jan Oblak
# 2              7               0  Rayo Vallecano       44  13,966  Jan Oblak
# 3              0               3        Valencia       63  45,363  Jan Oblak
# 4              1               1        it Lazio       51  46,168  Jan Oblak
#
#              Arbitro
# 0        Juan Pulido
# 1  Ricardo de Burgos
# 2  José Luis Munuera
# 3          Jesús Gil
# 4      Slavko Vinčič

# %%
# Limpiamos el resultado
resultados={"W":"Victoria", "D":"Empate", "L":"Derrota"}
df_jugados["Resultado"]=df_jugados["Resultado"].apply(lambda x: resultados[x])
df_jugados.head()
# Out:
#         Fecha    Hora       Competicion           Ronda      Lugar Resultado  \
# 0  2023-08-14  21:30            La Liga       Jornada 1      Local  Victoria
# 1  2023-08-20  21:30            La Liga       Jornada 2  Visitante    Empate
# 2  2023-08-28  21:30            La Liga       Jornada 3  Visitante  Victoria
# 3  2023-09-16  16:15            La Liga       Jornada 5  Visitante   Derrota
# 4  2023-09-19  21:00   Champions League  Fase de grupos  Visitante    Empate
#
#   Goles Marcados Goles Recibidos           Rival Posesion Publico    Capitan  \
# 0              3               1         Granada       46  56,164       Koke
# 1              0               0           Betis       47  51,782  Jan Oblak
# 2              7               0  Rayo Vallecano       44  13,966  Jan Oblak
# 3              0               3        Valencia       63  45,363  Jan Oblak
# 4              1               1        it Lazio       51  46,168  Jan Oblak
#
#              Arbitro
# 0        Juan Pulido
# 1  Ricardo de Burgos
# 2  José Luis Munuera
# 3          Jesús Gil
# 4      Slavko Vinčič

# %%
# Creamos el marcador
df_jugados["Marcador"]=df_jugados["Goles Marcados"]+" - "+df_jugados["Goles Recibidos"]
df_jugados.head()
# Out:
#         Fecha    Hora       Competicion           Ronda      Lugar Resultado  \
# 0  2023-08-14  21:30            La Liga       Jornada 1      Local  Victoria
# 1  2023-08-20  21:30            La Liga       Jornada 2  Visitante    Empate
# 2  2023-08-28  21:30            La Liga       Jornada 3  Visitante  Victoria
# 3  2023-09-16  16:15            La Liga       Jornada 5  Visitante   Derrota
# 4  2023-09-19  21:00   Champions League  Fase de grupos  Visitante    Empate
#
#   Goles Marcados Goles Recibidos           Rival Posesion Publico    Capitan  \
# 0              3               1         Granada       46  56,164       Koke
# 1              0               0           Betis       47  51,782  Jan Oblak
# 2              7               0  Rayo Vallecano       44  13,966  Jan Oblak
# 3              0               3        Valencia       63  45,363  Jan Oblak
# 4              1               1        it Lazio       51  46,168  Jan Oblak
#
#              Arbitro Marcador
# 0        Juan Pulido    3 - 1
# 1  Ricardo de Burgos    0 - 0
# 2  José Luis Munuera    7 - 0
# 3          Jesús Gil    0 - 3
# 4      Slavko Vinčič    1 - 1

# %%
# Funcion para limpiar el equipo de la champions (eliminar abreviatura pais)
def limpiarEquipoChampions(serie:pd.Series)->pd.Series:
    
    if serie["Competicion"] in ["Champions League", "Europa League"]:
        
        equipo_dividio=serie["Rival"].split(" ")[1:]
        
        equipo=" ".join(equipo_dividio)
        
        serie["Rival"]=equipo
        
    return serie

df_jugados[["Competicion", "Rival"]]=df_jugados[["Competicion", "Rival"]].apply(limpiarEquipoChampions, axis=1)
df_jugados.head()
# Out:
#         Fecha    Hora       Competicion           Ronda      Lugar Resultado  \
# 0  2023-08-14  21:30            La Liga       Jornada 1      Local  Victoria
# 1  2023-08-20  21:30            La Liga       Jornada 2  Visitante    Empate
# 2  2023-08-28  21:30            La Liga       Jornada 3  Visitante  Victoria
# 3  2023-09-16  16:15            La Liga       Jornada 5  Visitante   Derrota
# 4  2023-09-19  21:00   Champions League  Fase de grupos  Visitante    Empate
#
#   Goles Marcados Goles Recibidos           Rival Posesion Publico    Capitan  \
# 0              3               1         Granada       46  56,164       Koke
# 1              0               0           Betis       47  51,782  Jan Oblak
# 2              7               0  Rayo Vallecano       44  13,966  Jan Oblak
# 3              0               3        Valencia       63  45,363  Jan Oblak
# 4              1               1           Lazio       51  46,168  Jan Oblak
#
#              Arbitro Marcador
# 0        Juan Pulido    3 - 1
# 1  Ricardo de Burgos    0 - 0
# 2  José Luis Munuera    7 - 0
# 3          Jesús Gil    0 - 3
# 4      Slavko Vinčič    1 - 1

# %%
# Cambiamos el tipo del dato en la columna de la posesion
df_jugados["Posesion"]=df_jugados["Posesion"].astype(int)

# %%
# Funcion para limpiar la cantidad de publico
def limpiarPublico(cantidad:str)->int:
    
    cantidad_str=cantidad.replace(",", "")
    
    return int(cantidad_str)

df_jugados["Publico"]=df_jugados["Publico"].apply(limpiarPublico)
df_jugados.head()
# Out:
#         Fecha    Hora       Competicion           Ronda      Lugar Resultado  \
# 0  2023-08-14  21:30            La Liga       Jornada 1      Local  Victoria
# 1  2023-08-20  21:30            La Liga       Jornada 2  Visitante    Empate
# 2  2023-08-28  21:30            La Liga       Jornada 3  Visitante  Victoria
# 3  2023-09-16  16:15            La Liga       Jornada 5  Visitante   Derrota
# 4  2023-09-19  21:00   Champions League  Fase de grupos  Visitante    Empate
#
#   Goles Marcados Goles Recibidos           Rival  Posesion  Publico  \
# 0              3               1         Granada        46    56164
# 1              0               0           Betis        47    51782
# 2              7               0  Rayo Vallecano        44    13966
# 3              0               3        Valencia        63    45363
# 4              1               1           Lazio        51    46168
#
#      Capitan            Arbitro Marcador
# 0       Koke        Juan Pulido    3 - 1
# 1  Jan Oblak  Ricardo de Burgos    0 - 0
# 2  Jan Oblak  José Luis Munuera    7 - 0
# 3  Jan Oblak          Jesús Gil    0 - 3
# 4  Jan Oblak      Slavko Vinčič    1 - 1

# %%
# Nos quedamos con las columnas en el orden que queramos
df_final=df_jugados[["Fecha", "Hora", "Competicion", "Ronda", "Lugar", "Rival", "Marcador", "Resultado",
                    "Posesion", "Publico", "Capitan", "Arbitro"]]
df_final.head()
# Out:
#         Fecha    Hora       Competicion           Ronda      Lugar  \
# 0  2023-08-14  21:30            La Liga       Jornada 1      Local
# 1  2023-08-20  21:30            La Liga       Jornada 2  Visitante
# 2  2023-08-28  21:30            La Liga       Jornada 3  Visitante
# 3  2023-09-16  16:15            La Liga       Jornada 5  Visitante
# 4  2023-09-19  21:00   Champions League  Fase de grupos  Visitante
#
#             Rival Marcador Resultado  Posesion  Publico    Capitan  \
# 0         Granada    3 - 1  Victoria        46    56164       Koke
# 1           Betis    0 - 0    Empate        47    51782  Jan Oblak
# 2  Rayo Vallecano    7 - 0  Victoria        44    13966  Jan Oblak
# 3        Valencia    0 - 3   Derrota        63    45363  Jan Oblak
# 4           Lazio    1 - 1    Empate        51    46168  Jan Oblak
#
#              Arbitro
# 0        Juan Pulido
# 1  Ricardo de Burgos
# 2  José Luis Munuera
# 3          Jesús Gil
# 4      Slavko Vinčič

# %% [markdown]
# ### Guardado de los datos

# %%
df_final.to_csv(f"Partidos_ATM_{temporada.replace('-','_')}.csv", index=False)
